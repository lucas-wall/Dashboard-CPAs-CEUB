# %%
import pandas as pd

# %%
caminho_excel = 'CEUB_export-data-desafio-pbi.xlsx'

# %%
df = pd.read_excel(caminho_excel)

# %%
df
# Out:
#        Unnamed: 0 Código da Avaliação  \
# 0               0             EG20EAD
# 1               1             EG20EAD
# 2               2             EG20EAD
# 3               3             EG20EAD
# 4               4             EG20EAD
# ...           ...                 ...
# 99995       99995           EG24DVMD1
# 99996       99996           EG24DVMD1
# 99997       99997           EG24DVMD1
# 99998       99998           EG24DVMD1
# 99999       99999           EG24DVMD1
#
#                                        Nome da Avaliação  \
# 0      Avaliação do Ensino de Graduação pelo Discente...
# 1      Avaliação do Ensino de Graduação pelo Discente...
# 2      Avaliação do Ensino de Graduação pelo Discente...
# 3      Avaliação do Ensino de Graduação pelo Discente...
# 4      Avaliação do Ensino de Graduação pelo Discente...
# ...                                                  ...
# 99995                               Disciplinas Virtuais
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Código da Avaliação', 'Nome da Avaliação',
#        'Tipo da Avaliação', 'Grupo da Questão', 'Tipo da Questão',
#        'Número da Questão', 'Questão', 'Peso da Questão', 'Resposta',
#        'Peso da Resposta', 'Resposta Descritiva', 'Período Letivo',
#        'Ordenação Período Letivo', 'Ciclo Acadêmico',
#        'Ciclo Acadêmico - Letra', 'Nome do Campus', 'Tipo de Curso', 'Curso',
#        'Eixo de Formação', 'Unidade Funcional', 'Tipo de Ensino do Curso',
#        'Disciplina_Inv', 'Currículo', 'Currículo - Ano', 'Turma',
#        'Código da Turma', 'Professor', 'Regime Letivo',
#        'Forma Veiculação Ensino', 'Faixa MGA', 'AvaliacaoDimensao',
#        'AvaliacaoModalidade', 'EnsinoModalidade', 'NivelAcademico',
#        'GrupoResposta_ID', 'Curso EAD', 'Período Letivo - Ano',
#        'Período Letivo - Num', 'Turno - Turma', 'Período - Disciplina',
#        'Período de Análise Avaliação',
#        'Período de Análise Avaliação - Ordenacao',
# ...

# %%
df['Resposta'].unique()
# Out:
# array(['a) Concordo totalmente', 'b) Concordo em parte', '. ',
#        'd) Discordo em parte', 'e) Discordo totalmente',
#        'c) Nem concordo, nem discordo',
#        'f) Não sei / Não quero responder'], dtype=object)
